# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import streamlit as st 
def spotify():
    SPOTIPY_CLIENT_ID = '319830f7c85a4a02889ad9e1f41c90c6'
    SPOTIPY_CLIENT_SECRET = 'c6b21ccca01e4185a13484006481f189'

    auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
    sp = spotipy.Spotify(auth_manager=auth_manager)

    return sp

def get_top_tracks_info(artist_name, limit = 10):
    try:
        sp = spotify()

        artists = sp.search(q='artist:'+artist_name, type='artist', limit=10)
        artist_uri = artists['artists']['items'][0]['uri']
        results = sp.artist_top_tracks(artist_uri)

        track_result = []
        features_result = []

        for i, item in enumerate(results['tracks'][:limit]):
            track_id = item['id']
            track_name = item['name']
            popularity = item['popularity']
            preview_url = item['preview_url'] if 'preview_url' in item else 'N/A'
            cover_art = item['album']['images'][0]['url'] if 'album' in item and 'images' in item['album'] and item['album']['images'] else 'N/A'

            track_result.append((i, artist_name, track_id, track_name, popularity, preview_url, cover_art))

            # Pobranie informacji o funkcjach audio tylko raz
            audio_features = sp.audio_features(track_id)
            features_result.extend(audio_features)

        track_df = pd.DataFrame(track_result, columns=('Item', 'Artist', 'Id', 'Song Name', 'Popularity', 'Preview URL', 'Cover Art'))
        features_df = pd.DataFrame(features_result)

        final_df = pd.concat([track_df, features_df], axis=1)
        final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)

        return final_df_sorted

    except Exception as e:
        return f"Error: {e}"
# Uzyskanie informacji dla artysty "Travis Scott" dla 10 najlepszych utworów
analisis = get_top_tracks_info("Travis Scott", limit=10)

# Transpozycja DataFrame

# Wyświetlenie wyników
analisis
# Out:
#    Item        Artist                      Id  \
# 1     1  Travis Scott  6wsqVwoiVH2kde4k4KKAFU
# 2     2  Travis Scott  42VsgItocQwOQC3XWZ8JNA
# 3     3  Travis Scott  5wG3HvLhF6Y5KTGlK0IW3J
# 4     4  Travis Scott  6gBFPUFcJLzWGx4lenP6h2
# 5     5  Travis Scott  4kjI1gwQZRKNDkw1nI475M
# 6     6  Travis Scott  67nepsnrcZkowTxMWigSbb
# 7     7  Travis Scott  2xLMifQCjDGFmkHkpNLD9h
# 8     8  Travis Scott  1i9lZvlaDdWDPyXEE95aiq
# 9     9  Travis Scott  40iJIUlhi6renaREYGeIDS
# 0     0  Travis Scott  2Y4ImmYsxc4bclzGlmvlzo
#
#                                  Song Name  Popularity  \
# 1                                 I KNOW ?          92
# 2               FE!N (feat. Playboi Carti)          91
# 3  Trance (with Travis Scott & Young Thug)          89
# 4                               goosebumps          89
# 5                                  MY EYES          89
# 6                   MELTDOWN (feat. Drake)          87
# 7                               SICKO MODE          87
# 8         TELEKINESIS (feat. SZA & Future)          87
# 9           Fair Trade (with Travis Scott)          86
# 0                            Water - Remix          69
#
#                                          Preview URL  \
# 1  https://p.scdn.co/mp3-preview/71d86e04987feee6...
# 2  https://p.scdn.co/mp3-preview/4b0178cf6991f59d...
# 3                                               None
# 4  https://p.scdn.co/mp3-preview/5c45fee2743d3998...
# 5  https://p.scdn.co/mp3-preview/b52f66d1d36c1253...
# 6  https://p.scdn.co/mp3-preview/7c7e0e4419d101bc...
# 7  https://p.scdn.co/mp3-preview/8229545ded5cacf3...
# 8  https://p.scdn.co/mp3-preview/044ceba2a9451325...
# 9                                               None
# 0  https://p.scdn.co/mp3-preview/07c528e02c48da9b...
#
#                                            Cover Art  danceability  energy  \
# 1  https://i.scdn.co/image/ab67616d0000b273881d8d...         0.927   0.619
# 2  https://i.scdn.co/image/ab67616d0000b273881d8d...         0.569   0.882
# 3  https://i.scdn.co/image/ab67616d0000b273c4fee5...         0.571   0.549
# 4  https://i.scdn.co/image/ab67616d0000b273f54b99...         0.841   0.728
# 5  https://i.scdn.co/image/ab67616d0000b273881d8d...         0.455   0.621
# 6  https://i.scdn.co/image/ab67616d0000b273881d8d...         0.557   0.774
# 7  https://i.scdn.co/image/ab67616d0000b273072e9f...         0.834   0.730
# 8  https://i.scdn.co/image/ab67616d0000b273881d8d...         0.458   0.535
# 9  https://i.scdn.co/image/ab67616d0000b273cd945b...         0.666   0.465
# 0  https://i.scdn.co/image/ab67616d0000b273c2b58c...         0.739   0.749
#
#    key  ...  liveness  valence    tempo            type  \
# 1    5  ...     0.104    0.817  117.995  audio_features
# 2    3  ...     0.142    0.201  148.038  audio_features
# 3    1  ...     0.168    0.447  119.497  audio_features
# 4    7  ...     0.149    0.430  130.049  audio_features
# 5    0  ...     0.123    0.280  119.043  audio_features
# 6    7  ...     0.396    0.397  111.975  audio_features
# 7    8  ...     0.124    0.446  155.008  audio_features
# 8    5  ...     0.168    0.216   82.826  audio_features
# 9    1  ...     0.215    0.292  167.937  audio_features
# 0    6  ...     0.149    0.505  117.030  audio_features
#
#                        id                                   uri  \
# 1  6wsqVwoiVH2kde4k4KKAFU  spotify:track:6wsqVwoiVH2kde4k4KKAFU
# 2  42VsgItocQwOQC3XWZ8JNA  spotify:track:42VsgItocQwOQC3XWZ8JNA
# 3  5wG3HvLhF6Y5KTGlK0IW3J  spotify:track:5wG3HvLhF6Y5KTGlK0IW3J
# 4  6gBFPUFcJLzWGx4lenP6h2  spotify:track:6gBFPUFcJLzWGx4lenP6h2
# 5  4kjI1gwQZRKNDkw1nI475M  spotify:track:4kjI1gwQZRKNDkw1nI475M
# 6  67nepsnrcZkowTxMWigSbb  spotify:track:67nepsnrcZkowTxMWigSbb
# 7  2xLMifQCjDGFmkHkpNLD9h  spotify:track:2xLMifQCjDGFmkHkpNLD9h
# 8  1i9lZvlaDdWDPyXEE95aiq  spotify:track:1i9lZvlaDdWDPyXEE95aiq
# 9  40iJIUlhi6renaREYGeIDS  spotify:track:40iJIUlhi6renaREYGeIDS
# 0  2Y4ImmYsxc4bclzGlmvlzo  spotify:track:2Y4ImmYsxc4bclzGlmvlzo
#
#                                           track_href  \
# 1  https://api.spotify.com/v1/tracks/6wsqVwoiVH2k...
# 2  https://api.spotify.com/v1/tracks/42VsgItocQwO...
# 3  https://api.spotify.com/v1/tracks/5wG3HvLhF6Y5...
# 4  https://api.spotify.com/v1/tracks/6gBFPUFcJLzW...
# 5  https://api.spotify.com/v1/tracks/4kjI1gwQZRKN...
# 6  https://api.spotify.com/v1/tracks/67nepsnrcZko...
# 7  https://api.spotify.com/v1/tracks/2xLMifQCjDGF...
# 8  https://api.spotify.com/v1/tracks/1i9lZvlaDdWD...
# 9  https://api.spotify.com/v1/tracks/40iJIUlhi6re...
# 0  https://api.spotify.com/v1/tracks/2Y4ImmYsxc4b...
#
#                                         analysis_url duration_ms  \
# 1  https://api.spotify.com/v1/audio-analysis/6wsq...      211582
# 2  https://api.spotify.com/v1/audio-analysis/42Vs...      191701
# 3  https://api.spotify.com/v1/audio-analysis/5wG3...      194787
# 4  https://api.spotify.com/v1/audio-analysis/6gBF...      243837
# 5  https://api.spotify.com/v1/audio-analysis/4kjI...      251250
# 6  https://api.spotify.com/v1/audio-analysis/67ne...      246134
# 7  https://api.spotify.com/v1/audio-analysis/2xLM...      312820
# 8  https://api.spotify.com/v1/audio-analysis/1i9l...      353755
# 9  https://api.spotify.com/v1/audio-analysis/40iJ...      291175
# 0  https://api.spotify.com/v1/audio-analysis/2Y4I...      200256
#
#   time_signature
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              4
# 9              4
# 0              4
#
# [10 rows x 25 columns]
